# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# gerando uma massa de dados
# generation a fake data
#n_sample=quantity
#n_features=number of variables
#noise=how much my data hath dispearse
x, y = make_regression(n_samples=200, n_features=1, noise=10)
plt.scatter(x,y)
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 0.6061820639877127

# %%
model.coef_
# Out:
# array([13.49320156])

# %% [markdown]
# import

# %%
import numpy as np


plt.scatter(x, y)
xreg = np.arange(-3, 3, 1)

coef = np.round(model.coef_, 2)
intercept = np.round(model.intercept_, 2)

plt.plot(xreg, coef*xreg-intercept)
